# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df_iris = sns.load_dataset('iris')
df_iris.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(df_iris, hue='species')

# %% [markdown]
# # Calculating Correlations

# %%
df_iris.drop(columns=['species']).corr(method='pearson').style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5e420_row0_col0, #T_5e420_row1_col1, #T_5e420_row2_col2, #T_5e420_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5e420_row0_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_5e420_row0_col2 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_5e420_row0_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_5e420_row1_col0, #T_5e420_row1_col2, #T_5e420_row1_col3, #T_5e420_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_5e420_row2_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_5e420_row2_col3, #T_5e420_row3_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_5e420_row3_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_5e420_row3_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5e420">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5e420_level0_col0" class="col_heading level0 col0" >sepal_length</th>
#       <th id="T_5e420_level0_col1" class="col_heading level0 col1" >sepal_width</th>
#       <th id="T_5e420_level0_col2" class="col_heading level0 col2" >petal_length</th>
#       <th id="T_5e420_level0_col3" class="col_heading level0 col3" >petal_width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e420_level0_row0" class="row_heading level0 row0" >sepal_length</th>
#       <td id="T_5e420_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_5e420_row0_col1" class="data row0 col1" >-0.117570</td>
#       <td id="T_5e420_row0_col2" class="data row0 col2" >0.871754</td>
#       <td id="T_5e420_row0_col3" class="data row0 col3" >0.817941</td>
#     </tr>
#     <tr>
#       <th id="T_5e420_level0_row1" class="row_heading level0 row1" >sepal_width</th>
#       <td id="T_5e420_row1_col0" class="data row1 col0" >-0.117570</td>
#       <td id="T_5e420_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_5e420_row1_col2" class="data row1 col2" >-0.428440</td>
#       <td id="T_5e420_row1_col3" class="data row1 col3" >-0.366126</td>
#     </tr>
#     <tr>
#       <th id="T_5e420_level0_row2" class="row_heading level0 row2" >petal_length</th>
#       <td id="T_5e420_row2_col0" class="data row2 col0" >0.871754</td>
#       <td id="T_5e420_row2_col1" class="data row2 col1" >-0.428440</td>
#       <td id="T_5e420_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_5e420_row2_col3" class="data row2 col3" >0.962865</td>
#     </tr>
#     <tr>
#       <th id="T_5e420_level0_row3" class="row_heading level0 row3" >petal_width</th>
#       <td id="T_5e420_row3_col0" class="data row3 col0" >0.817941</td>
#       <td id="T_5e420_row3_col1" class="data row3 col1" >-0.366126</td>
#       <td id="T_5e420_row3_col2" class="data row3 col2" >0.962865</td>
#       <td id="T_5e420_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The strongest correlation happens betwen petal_width and petal_length. On the plot it is visible that the points are very close to a straight line. Other two most corelated pairs of features are petal_length and petal_width with sepal_length. Sepal width is not correlated with any other feature, and we can observe that the points are scattered all over the plot.

# %%
features_iris = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
x_iris = df_iris.loc[:, features_iris].values

# %%
y_iris = df_iris.loc[:,['species']].values

# %%
x_iris = StandardScaler().fit_transform(x_iris)

# %%
df_iris_standarize = pd.DataFrame(data = x_iris, columns = features_iris)
df_iris_standarize['species'] = df_iris['species']
df_iris_standarize.head(15)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0      -0.900681     1.019004     -1.340227    -1.315444  setosa
# 1      -1.143017    -0.131979     -1.340227    -1.315444  setosa
# 2      -1.385353     0.328414     -1.397064    -1.315444  setosa
# 3      -1.506521     0.098217     -1.283389    -1.315444  setosa
# 4      -1.021849     1.249201     -1.340227    -1.315444  setosa
# 5      -0.537178     1.939791     -1.169714    -1.052180  setosa
# 6      -1.506521     0.788808     -1.340227    -1.183812  setosa
# 7      -1.021849     0.788808     -1.283389    -1.315444  setosa
# 8      -1.748856    -0.362176     -1.340227    -1.315444  setosa
# 9      -1.143017     0.098217     -1.283389    -1.447076  setosa
# 10     -0.537178     1.479398     -1.283389    -1.315444  setosa
# 11     -1.264185     0.788808     -1.226552    -1.315444  setosa
# 12     -1.264185    -0.131979     -1.340227    -1.447076  setosa
# 13     -1.870024    -0.131979     -1.510739    -1.447076  setosa
# 14     -0.052506     2.169988     -1.453901    -1.315444  setosa

# %%
sns.pairplot(df_iris_standarize, hue='species')

# %%
df_iris_standarize.drop(columns=['species']).corr(method='pearson').style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6b678_row0_col0, #T_6b678_row1_col1, #T_6b678_row2_col2, #T_6b678_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6b678_row0_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_6b678_row0_col2 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_6b678_row0_col3 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_6b678_row1_col0, #T_6b678_row1_col2, #T_6b678_row1_col3, #T_6b678_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6b678_row2_col0 {
#   background-color: #da5a49;
#   color: #f1f1f1;
# }
# #T_6b678_row2_col3, #T_6b678_row3_col2 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_6b678_row3_col0 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_6b678_row3_col1 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6b678">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b678_level0_col0" class="col_heading level0 col0" >sepal_length</th>
#       <th id="T_6b678_level0_col1" class="col_heading level0 col1" >sepal_width</th>
#       <th id="T_6b678_level0_col2" class="col_heading level0 col2" >petal_length</th>
#       <th id="T_6b678_level0_col3" class="col_heading level0 col3" >petal_width</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b678_level0_row0" class="row_heading level0 row0" >sepal_length</th>
#       <td id="T_6b678_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_6b678_row0_col1" class="data row0 col1" >-0.117570</td>
#       <td id="T_6b678_row0_col2" class="data row0 col2" >0.871754</td>
#       <td id="T_6b678_row0_col3" class="data row0 col3" >0.817941</td>
#     </tr>
#     <tr>
#       <th id="T_6b678_level0_row1" class="row_heading level0 row1" >sepal_width</th>
#       <td id="T_6b678_row1_col0" class="data row1 col0" >-0.117570</td>
#       <td id="T_6b678_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_6b678_row1_col2" class="data row1 col2" >-0.428440</td>
#       <td id="T_6b678_row1_col3" class="data row1 col3" >-0.366126</td>
#     </tr>
#     <tr>
#       <th id="T_6b678_level0_row2" class="row_heading level0 row2" >petal_length</th>
#       <td id="T_6b678_row2_col0" class="data row2 col0" >0.871754</td>
#       <td id="T_6b678_row2_col1" class="data row2 col1" >-0.428440</td>
#       <td id="T_6b678_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_6b678_row2_col3" class="data row2 col3" >0.962865</td>
#     </tr>
#     <tr>
#       <th id="T_6b678_level0_row3" class="row_heading level0 row3" >petal_width</th>
#       <td id="T_6b678_row3_col0" class="data row3 col0" >0.817941</td>
#       <td id="T_6b678_row3_col1" class="data row3 col1" >-0.366126</td>
#       <td id="T_6b678_row3_col2" class="data row3 col2" >0.962865</td>
#       <td id="T_6b678_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
pca_iris = PCA(n_components=2)

# %%
principalComponents_iris = pca_iris.fit_transform(x_iris)

# %%
principalDf_iris = pd.DataFrame(data = principalComponents_iris ,columns = ['principal component 1', 'principal component 2'])

# %%
finalDf_iris = pd.concat([principalDf_iris, df_iris[['species']]], axis = 1)
finalDf_iris.head(15)
# Out:
#     principal component 1  principal component 2 species
# 0               -2.264703               0.480027  setosa
# 1               -2.080961              -0.674134  setosa
# 2               -2.364229              -0.341908  setosa
# 3               -2.299384              -0.597395  setosa
# 4               -2.389842               0.646835  setosa
# 5               -2.075631               1.489178  setosa
# 6               -2.444029               0.047644  setosa
# 7               -2.232847               0.223148  setosa
# 8               -2.334640              -1.115328  setosa
# 9               -2.184328              -0.469014  setosa
# 10              -2.166310               1.043691  setosa
# 11              -2.326131               0.133078  setosa
# 12              -2.218451              -0.728676  setosa
# 13              -2.633101              -0.961507  setosa
# 14              -2.198741               1.860057  setosa

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x=finalDf_iris['principal component 1'],
                y=finalDf_iris['principal component 2'],
                hue=finalDf_iris['species'],
                palette=['red', 'green', 'blue'],
                alpha=0.7)
plt.xlabel('principal component 1')
plt.ylabel('principal component 2')
plt.title('Wizualizacja PCA dla Iris')
plt.show()

# %%
pca_iris.explained_variance_ratio_
# Out:
# array([0.72962445, 0.22850762])
